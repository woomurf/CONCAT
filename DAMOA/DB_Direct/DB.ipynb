# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('C:/Users/dngus/dev/2019Summer/CONCAT/LinaCrwaling/chromdriver_win32/chromedriver.exe')
url = 'https://www.directdb.co.kr/product/ltm/custInfoLtm.do?searchPdcCd=30581&searchPdcTrtHistCd=00&pdcDvcd=l_tooth' 
driver.get(url)

# %%
# 가입 연령은 2세 ~ 70세 
# 미성년자와 성인 구분되어 있음. 
# 자녀형과 성인형 구분하여 함수 선언

def inputChild() : 
    
    # 만 2세 부터 만 18세까지 
    # 만 2세부터 만 7세는 미취학 아동으로, 그 이후는 초중고 학생으로 분류하도록 한다. 
    
    # 자녀형 선택
    driver.find_element_by_class_name("li01").click()
    
    driver.find_element_by_id('birthday').send_keys(age)
    
    sexes = driver.find_element_by_class_name('ico_sex').find_elements_by_class_name('input_radio')
    
    for sex in sexes : 
        sex.find_element_by_tag_name('span').click()
        
        jobkids = driver.find_element_by_class_name('label_horizental').find_elements_by_tag_name('li')
        jobkids[0].find_element_by_tag_name('span').click()
        
        driver.find_element_by_class_name('btn_foot').click()

# %%
driver.find_element_by_class_name("li01").click()

# %%
driver.find_element_by_id('birthday').send_keys('20050730')

# %%
sexes = driver.find_element_by_class_name('ico_sex').find_elements_by_class_name('input_radio')

# %%
sexes[1].find_element_by_tag_name('span').click()

# %%
jobkids = driver.find_element_by_class_name('label_horizental').find_elements_by_tag_name('li')

# %%
jobkids[1].find_element_by_tag_name('span').click()

# %%
driver.find_element_by_class_name('btn_foot').click()

# %%
driver.find_element_by_class_name('plan_select')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2232b6a8abc0e75e7b82bbf454a29568", element="73a72aba-2e1d-423b-bec6-18696611f6df")>

# %%
driver.get_cookie('CMKSESSIONID')
# Out:
# {'domain': 'www.directdb.co.kr',
#  'httpOnly': True,
#  'name': 'CMKSESSIONID',
#  'path': '/',
#  'secure': False,
#  'value': '00012aX6n2qrzeE16V4smirdBRV:1aafrjf7l'}

# %%
import requests

# %%
CMKSESSIONID = driver.get_cookie('CMKSESSIONID')['value']

# %%
driver.get_cookies()
# Out:
# [{'domain': 'www.directdb.co.kr',
#   'httpOnly': False,
#   'name': 'sessionExpiry',
#   'path': '/',
#   'secure': False,
#   'value': '1564474074542'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1627544874,
#   'httpOnly': False,
#   'name': '_ga',
#   'path': '/',
#   'secure': False,
#   'value': 'GA1.3.413355672.1564472866'},
#  {'domain': 'www.directdb.co.kr',
#   'httpOnly': False,
#   'name': 'clientTimeOffset',
#   'path': '/',
#   'secure': False,
#   'value': '688'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1609459200.006926,
#   'httpOnly': False,
#   'name': 'ccvisit',
#   'path': '/',
#   'secure': False,
#   'value': '20190730164753'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1609459200.006901,
#   'httpOnly': False,
#   'name': 'ccguid',
#   'path': '/',
#   'secure': False,
#   'value': '201907301647530a0a201a012c406ffc'},
#  {'domain': 'www.directdb.co.kr',
#   'expiry': 1595231274,
#   'httpOnly': False,
#   'name': 'DMP_SCRIPT_UUID',
#   'path': '/product/ltmSimple',
#   'secure': False,
#   'value': '098111ab-4924-a617-b18d-f2c65c0099e9'},
#  {'domain': 'directdb.co.kr',
#   'httpOnly': False,
#   'name': 'CUR_STAMP',
#   'path': '/',
#   'secure': False,
#   'value': '1564472866479'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1572248876,
#   'httpOnly': False,
#   'name': '_fbp',
#   'path': '/',
#   'secure': False,
#   'value': 'fb.2.1564472866914.1978115794'},
#  {'domain': 'www.directdb.co.kr',
#   'expiry': 1567064866,
#   'httpOnly': False,
#   'name': 'adn_uid',
#   'path': '/',
#   'secure': False,
#   'value': 'MTI1LjE0Mi4xNzcuMTc1XzE1NjQ0NzI4NjY='},
#  {'domain': 'www.directdb.co.kr',
#   'expiry': 1596008864.363175,
#   'httpOnly': False,
#   'name': 'WMONID',
#   'path': '/',
#   'secure': False,
#   'value': 'DBp25V6IyBJ'},
#  {'domain': 'www.directdb.co.kr',
#   'httpOnly': True,
#   'name': 'CMKSESSIONID',
#   'path': '/',
#   'secure': False,
#   'value': '0001pRNoFwFBVZ19zQBRWgv9s34:1aafrjgke'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1879832866,
#   'httpOnly': False,
#   'name': '_CHAT_DEVICEID',
#   'path': '/',
#   'secure': False,
#   'value': '16C41D976B0'},
#  {'domain': 'www.directdb.co.kr',
#   'httpOnly': False,
#   'name': 'serverTime',
#   'path': '/',
#   'secure': False,
#   'value': '1564472874542'},
#  {'domain': 'www.directdb.co.kr',
#   'expiry': 1595576866,
#   'httpOnly': False,
#   'name': 'ACEFBID',
#   'path': '/',
#   'secure': False,
#   'value': '42HVEI4XCPXFQ83699CSJAMZQ'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1564559274,
#   'httpOnly': False,
#   'name': '_gid',
#   'path': '/',
#   'secure': False,
#   'value': 'GA1.3.1705668231.1564472866'},
#  {'domain': 'directdb.co.kr',
#   'httpOnly': False,
#   'name': 'ccsession',
#   'path': '/',
#   'secure': False,
#   'value': '201907301647530a0a201a012c406ffc'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1564472926,
#   'httpOnly': False,
#   'name': '_gat_gtag_UA_106551931_1',
#   'path': '/',
#   'secure': False,
#   'value': '1'},
#  {'domain': 'directdb.co.kr',
#   'httpOnly': False,
#   'name': 'TLTSID',
#   'path': '/',
#   'secure': False,
#   'value': 'L4KCMRQT2LSHFFTCTXT9KYGKOQXV9KCJ'},
#  {'domain': 'www.directdb.co.kr',
#   'expiry': 1595576866,
#   'httpOnly': False,
#   'name': 'ACEFCID',
#   'path': '/',
#   'secure': False,
#   'value': 'UID-5D3FF622855B7628C8279D6C'},
#  {'domain': 'directdb.co.kr',
#   'expiry': 1627544874,
#   'httpOnly': False,
#   'name': '_kyp',
#   'path': '/',
#   'secure': False,
#   'value': 'QEkQBZnIBe1RpUI9Gvl7TDJSFrfO+YJb14neYBmoGnKW2IOzKcpglvXid9nYbRjgpi4pnAboScIg4A_.directdb.co.kr'},
#  {'domain': 'www.directdb.co.kr',
#   'expiry': 1564503970,
#   'httpOnly': False,
#   'name': 'AFCVAG4A385211163',
#   'path': '/',
#   'secure': False,
#   'value': '598e0-1564472866412-957871341715ea61'},
#  {'domain': 'directdb.co.kr',
#   'httpOnly': False,
#   'name': '_kys',
#   'path': '/',
#   'secure': False,
#   'value': 'QEkREjnaR+EuYA_.directdb.co.kr'},
#  {'domain': 'www.directdb.co.kr',
#   'httpOnly': False,
#   'name': 'APIDAG4A385211163',
#   'path': '/',
#   'secure': False,
#   'value': '2'},
#  {'domain': 'www.directdb.co.kr',
#   'httpOnly': False,
#   'name': 'ACEUCI',
#   'path': '/product/ltmSimple',
#   'secure': False,
#   'value': '1'}]

# %% [markdown]
# **selenium으로 고객정보 입력
# selenium으로 cookie를 읽어와서 CMKSESSIONID 얻기
# getLtmPlan.do 에 request 보내기 ( CMKSESSIONID 이용 )
# request보내어 얻은 것을 바탕으로 보장 내역 고유 코드를 얻어오기
# ajaxLtmCalc.do 에 request를 보내기 ( 보장 내역 고유 코드 이용 )
# 보험료 크롤링**

# %%
getLtmPlan_data = 'searchPdcCd=30581&searchPdcTrtHistCd=01&pdcDvcd=l_tooth&simpleInput=true&oprtVhDvcd=99&birthday=20050730&sxCd=2&_csrf=' + _csrf

# %%
getLtm_header = {
    'Content-Type' : 'application/x-www-form-urlencoded',
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36',
    'Referer' : 'https://www.directdb.co.kr/product/ltm/custInfoLtm.do?searchPdcCd=30581&searchPdcTrtHistCd=00&pdcDvcd=l_tooth'
}

getLtm_cookie = {
    'CMKSESSIONID' : CMKSESSIONID
}

# %%
import requests

# %%
response = requests.post('https://www.directdb.co.kr/product/ltmSimple/getLtmPlan.do', headers = getLtm_header, data = getLtmPlan_data,cookies = getLtm_cookie)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7]><html lang="ko" class="ie7"><![endif]-->
# <!--[if IE 8]><html lang="ko" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="ko" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html lang="ko">
# <!--<![endif]-->
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="DB손해보험" name="keywords"/>
# <meta content="" name="description"/>
# <title>보험료 확인하기 | 치아보험 | DB손해보험 다이렉트</title>
# <!-- Emforce Neo Script : 해외여행자 외 전상품 include -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-106551931-1"></script>
# <script>
#     try {
#          window.dataLayer = window.dataLayer || [];
#          function gtag(){dataLayer.push(arguments);}
#          gtag('js', new Date());
#
#          gtag('config', 'UA-106551931-1');
#     }
#     catch(e) {
#         LOG("===========Google Analytics Script Error!!===================");
#         LOG(e);
#     }
#     </script>
# <!-- Global site tag (gtag.js) - Google Analytics End -->
# <script src="/emforce/general_gd.js" type="text/javascript"></script>
# <!-- 엠포스 스크립트 삽입 공통 -->
# <script>
# 		window.emfAsyncInit = function() {
# 		};
# 		//load asynchronously
# 		(function(d,s,id){
#
# 		    var js, ejs = d.getElementsByTagName(s)[0];
#
# 		    if(d.getElementById(id)) {
# 		        return;
# 		    }
#
# 		    js = d.createElement(s);
# 		    js.id = id;
# 		    js.src = "//roi.emforce.co.kr/conversion/conversion_dt.js";
#
# 		    ejs.parentNode.insertBefore(js,ejs);
#
# 		}(document,'script','emforce-jssdk'));
# 	</script>
# <!-- 엠포스 스크립트 삽입 공통 -->
# <script charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script>
# <script>
# 	        function gaCall(stepId){
# 			    try {
# 			        gtag('event', 'event_name', {'event_category':stepId,'event_action':'click'});
# 			    }
# 			    catch(e){
# 			    }
# 			}
# 	        function emfConvCall(custId, convId, salesPrice, dir, category){
# 	            try {
# 	                Emf.convCall(custId, convId, salesPrice, dir, category);
# 	            }
# 	            catch(e){
# 	            }
# 	        }
# 	        // 일반보험 > 여행자보험 중 해외여행자보험상품 외는 아래 함수 호출
#             function emfIlbanConvCall(advertiserId, roiId, salesPrice, directory, category){
#                 LOG("===========Emforce ROI Conversion Tag commonEmforceIlbanScript[3]===================");
#                 return;
#             }
#         </script>
# <script>
#             function kakaoCall(sendPdcDvcd, actionCode){
#                 try {
#
#                     // 운전자를 기본으로 한다
#                     var stepId = "8242884007033916254";
#
#                     if(sendPdcDvcd == "l_driver"){
#                         stepId = "8242884007033916254";
#                     }
#                     else if(sendPdcDvcd == "l_tooth"){
#                         stepId = "543635977049128357";
#                     }
#                     else if(sendPdcDvcd == "l_pmi"){
#                         stepId = "6195571132676197427";
#                     }
#                     else {
#                         // 해당되는 보종이 아니면 돌려보낸다
#                         return;
#                     }
#
#                     kakaoPixel(stepId).pageView();
#
#                     if(actionCode == "search"){
#                         kakaoPixel(stepId).search({
#                             tag: '2단계_보험료산출'
#                           });
#                     }
#                     else if (actionCode == "viewContent"){
#                         kakaoPixel(stepId).viewContent({
#                             tag: '5단계_본인인증'
#                           });
#                     }
#                     else if (actionCode == "completeRegistration"){
#                         kakaoPixel(stepId).completeRegistration('8단계_청약완료');
#                     }
#                 }
#                 catch(e){
#                 }
#             }
#         </script>
# <script type="text/javascript">
#             var contextPath = '';
#         </script>
# <script type="text/javascript">
#
# var isViewConsole = '0';
#
# </script>
# <!-- 10.10.32.25 -->
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/js/libs/jquery/jquery.loadmask.css?v=1.0.6.121" rel="stylesheet" type="text/css"/>
# <link href="/css/reset.css?v=1.0.6.121" rel="stylesheet" type="text/css"/>
# <link href="/css/popup.css?v=1.0.6.121" rel="stylesheet" type="text/css"/>
# <script src="/js/libs/jquery/jquery-1.11.3.js" type="text/javascript"></script>
# <script src="/js/libs/jquery/jquery-ui-1.11.4/jquery-ui.js" type="text/javascript"></script>
# <script src="/js/libs/jquery/jquery.loadmask.min.js" type="text/javascript"></script>
# <script src="/js/dbcm/common/ajax_util.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/libs/autoNumeric-min.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/libs/jquery/jquery.validate.min.js" type="text/javascript"></script>
# <script src="/js/libs/jquery/jquery.fileupload.js" type="text/javascript"></script>
# <script src="/js/libs/jquery/jquery.iframe-transport.js" type="text/javascript"></script>
# <script src="/js/libs/jquery/jQuery.print.js" type="text/javascript"></script>
# <script src="/js/dbcm/common/common.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/common_ui.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/input_handler.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/libs/jquery/jquery.placeholder.min.js" type="text/javascript"></script>
# <script src="/js/dbcm/publish/ui_common.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/publish/plugins.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/validator.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/formatter.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/masker.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/checkbox_handler.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/radio_handler.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/list_appender.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/popup/commonPopup_layer.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/printer.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/auth/auth_form_errors.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/popup/terms_layer.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/popup/cnslaply_layer.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/popup/cnslaply_layer2.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/customer/faq/faqList_layer.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/popup/us_ltpd_layer.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/properties.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/menu_click_cnt.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/en_ko_util.js?v=1.0.6.121" type="text/javascript"></script>
# <!-- new header -->
# <script src="/js/libs/tag_dongbu.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/tealeaf/js/tealeaf.js?v=1.0.6.121" type="text/javascript"></script>
# <script type="text/javascript">
#
# function calcOffset() {
#     try {
#         var serverTime = gfnGetCookie('serverTime');
#         serverTime = serverTime==null ? null : Math.abs(serverTime);
#         var clientTimeOffset = (new Date()).getTime() - serverTime;
#         gfnSetCookie('clientTimeOffset',clientTimeOffset,'session');
#     }catch(e) {
#         LOG(e);
#     }
# }
#
# $(document).ready(function() {
#     calcOffset();
# });
# </script>
# <link href="/css/common.css?v=1.0.6.121" rel="stylesheet" type="text/css"/>
# <link href="/css/ltmgnrl.css?v=1.0.6.121" rel="stylesheet" type="text/css"/>
# <form action="/product/ltmSimple/getLtmPlan.do" id="tagForm" method="POST">
# <input id="preTagId" name="preTagId" type="hidden" value="pre_02_01"/>
# <input id="nextTagId" name="nextTagId" type="hidden" value="next_02_01"/>
# <div>
# <input name="_csrf" type="hidden" value="0887e990-252c-4ac6-9b29-aa5c627b36b4">
# </input></div></form>
# <!--  KaizenScript 삽입 공통(항상 header 맨 밑에 위치)  -->
# <script type="text/javascript">
# LOG("isLoadKaizenYn ============> 1");
# LOG("serverNameHeader ============> www.directdb.co.kr");
# </script>
# <!-- 카이젠 스크립트 삽입 공통(항상 header 맨 밑에 위치) -->
# <script charset="utf-8" data-kz-key="36fff490af0659d9" data-kz-namespace="kzs" src="//cdn.kaizenplatform.net/s/36/fff490af0659d9.js"></script>
# <!-- 카이젠 스크립트 삽입 공통(항상 header 맨 밑에 위치) -->
# <!-- SKP 데이터수집 Script -->
# <script type="text/javascript">
#     try {
#         function skpCreateTag(tmpAction) {
#             LOG('skpCreateTag.tmpAction:::'+ tmpAction);
#             //var temp_url = 'http://idm-alp.skplanet.com/v2/collect?data=';  // Develop
#             // service
#             var temp_url = 'https://idm.skplanet.com/v2/collect?data=';
#             var data = encodeURIComponent('{"authkey":"c57c8c25828d427e98b7320dd199ca5a","channel":"web","lsid":"1003","action":"' + tmpAction + '"}');
#             var img = '<img src="' + temp_url + data + '" width="0" height="0">';
#             //LOG('img='+ img );
#             //document.write(img);
#             $('#skpBody').append(img);
#         }
#     }
#     catch(e) {
#         LOG("===========SKP 데이터수집 Script Error!!===================");
#         LOG(e);
#     }
#     </script>
# <div id="skpBody" style="display: none;"></div>
# <!-- SKP 데이터수집 Script End -->
# </head>
# <body>
# <div class="skipnav">
# <a href="#contents">본문바로가기</a>
# </div>
# <!--id="wrap"에 class별로 상품별 구분이 이루어 짐. 아래 class명 페이지 별로 확인해야함-->
# <div class="wrap_sub tooth" id="wrap">
# <div id="header">
# <div class="wrap_header">
# <h1>
# <!--<a href="/main.do">-->
# <a class="btn_close_logo" href="/main.do" onclick="javascript:gfnOpenLayer($('#ltmGnrlBannerLayer')); return false;">
# <img alt="DB손해보험 다이렉트 메인으로 가기" src="/images/common/logo03.png"/>
# <img alt="DB손해보험 다이렉트 메인으로 가기" src="/images/product/common/logo01.png"/>
# <img alt="DB손해보험 다이렉트 메인으로 가기" src="/images/product/common/logo02.png"/>
# </a>
# </h1>
# <div class="wrap_calc_process">
# <ol class="calc_preocess clfix">
# <!-- 이미 진행된 스탭은 class end 추가-->
# <li class="end">
# <span></span>
# <strong>1.고객정보</strong>
# <em class="hide_txt">현재 위치 입니다.</em>
# </li>
# <!-- 이미 진행된 스탭은 class end 추가-->
# <li class="active">
# <span></span>
# <strong>2.보험료 확인하기</strong>
# <em class="hide_txt">현재 위치 입니다.</em>
# </li>
# <!-- 이미 진행된 스탭은 class end 추가-->
# <li class="">
# <span></span>
# <strong>3.피보험자/계약자 정보</strong>
# <em class="hide_txt">현재 위치 입니다.</em>
# </li>
# <!-- 현재 진행 중인 스탭은 class active 추가-->
# <li class="">
# <span></span>
# <strong>4.청약내용 확인</strong>
# <em class="hide_txt">현재 위치 입니다.</em>
# </li>
# <!--마지막 스탭은 class last를 기본으로 넣어야 함 활성화 시에는 class='last active'로 표시-->
# <li class="last">
# <span></span>
# <strong>5.보험료 결제</strong>
# <em class="hide_txt">현재 위치 입니다.</em>
# </li>
# </ol>
# </div>
# <a class="btn_close" href="/main.do" onclick="javascript:gfnOpenLayer($('#ltmGnrlBannerLayer')); return false;">
# <em class="hide_txt">창닫기</em>
# </a>
# </div>
# <!-- 이탈팝업 추가 -->
# <div class="wrap_popup" id="ltmGnrlBannerLayer" style="display: none">
# <div class="dimm" style="display:block"></div>
# <div class="wrap_container w600_bd">
# <div class="wrap_pop">
# <div class="wrap_cont_sc">
# <div class="wrap_pop_cont">
# <div class="wrap_info_bn_end">
# <a href="/product/ltm/custInfoLtm.do?searchPdcCd=30581&amp;searchPdcTrtHistCd=00&amp;pdcDvcd=l_tooth">
# <img alt="" src="/images/ecrm/img_bn_end08.jpg" style="width:500px; height:auto"/>
# </a>
# </div>
# <div class="btn_center">
# <a class="btns btn_pop_green" href="/product/ltm/custInfoLtm.do?searchPdcCd=30581&amp;searchPdcTrtHistCd=00&amp;pdcDvcd=l_tooth">
# <span>알아보기</span>
# </a>
# <a class="btns btn_pop_green" href="/main.do">
# <span>종료</span>
# </a>
# </div>
# </div>
# </div>
# <div class="wrap_pop_foot">
# <a class="btn_pop_close green" href="#" onclick="javascript:gfnCloseLayer($('#ltmGnrlBannerLayer')); return false;">
# <em class="hide_txt">닫기</em>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clfix" id="container">
# <div id="lnb">
# <script src="/js/dbcm/product/ltmgnrl/lnb.js" type="text/javascript"></script>
# <form action="/product/ltmSimple/getLtmPlan.do" id="lnbForm" method="POST">
# <input name="searchPdcCd" type="hidden" value="30581"/>
# <input name="searchPdcTrtHistCd" type="hidden" value="01"/>
# <input name="pdcDvcd" type="hidden" value="l_tooth"/>
# <input id="lnbPdcDvcd" name="lnbPdcDvcd" type="hidden" value="l_tooth"/>
# <input id="step1_url" name="step1_url" type="hidden" value="/product/ltm/custInfoLtm.do"/>
# <h2>
# <em></em>
# <span>치아보험</span>
# </h2>
# <ol class="process_step">
# <li>
# <p class="step_ttl">1. 고객정보 </p>
# <ul>
# <li>만 14세 / 여자</li>
# <li>초·중·고 학생</li>
# </ul>
# <a class="btns btn_step_mod" href="#" onclick="javascript:ltmgnrlLnb.actMoveStep(1, '/product/ltm/custInfoLtm.do'); return false;">
# <span>수정</span>
# </a>
# </li>
# </ol>
# <div class="mgt20" id="cocmDiv">
# </div>
# <div>
# <input name="_csrf" type="hidden" value="0887e990-252c-4ac6-9b29-aa5c627b36b4">
# </input></div></form>
# </div>
# <div id="contents">
# <script src="/js/dbcm/product/ltmgnrl/ltmgnrlCommon.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/product/ltmgnrl/calculate_ltm.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/common/code/commonCode.js?v=1.0.6.121" type="text/javascript"></script>
# <script src="/js/dbcm/product/common/popLtmGnrlPartner.js?v=1.0.6.121" type="text/javascript"></script>
# <script type="text/javascript">
# var TNK_SR = '5c737d2a6dd5b3de5ff31f59da0a684d';     //raonsecure TouchEnKey Create session Random
# </script>
# <script type="text/javascript">
# $(document).ready(function () {
#
#         var errMsg = "";
#         if(errMsg != ""){
#             alert(errMsg);
#         }
#     });
# </script>
# <form action="/product/ltmSimple/getLtmPlan.do" id="sForm" method="POST">
# <input id="searchPdcCd" name="searchPdcCd" type="hidden" value="30581">
# <input id="searchArcAg" name="searchArcAg" type="hidden" value="14">
# <input id="searchIntAg" name="searchIntAg" type="hidden" value="14">
# <input id="searchSlPanCd" name="searchSlPanCd" type="hidden" value="21">
# <input id="searchPymMtdCd" name="searchPymMtdCd" type="hidden" value="01">
# <input id="searchPdcTrtHistCd" name="searchPdcTrtHistCd" type="hidden" value="01"/>
# <input id="searchCvrCds" name="searchCvrCds" type="hidden" value="[307677, 305031, 305093, 305100, 307682, 307667]"/>
# <input id="searchPlanAgeCd" name="searchPlanAgeCd" type="hidden" value=""/>
# <input id="dupCvrCds" name="dupCvrCds" type="hidden" value=""/>
# <input id="dupPrceCvrCds" name="dupPrceCvrCds" type="hidden" value=""/>
# <input id="searchCalcType" name="searchCalcType" type="hidden"/>
# <input id="reCalcYn" name="reCalcYn" type="hidden" value=""/>
# <input id="atArcEnyYn" name="atArcEnyYn" type="hidden" value=""/><!-- 자동차보험 기가입여부  -->
# <input id="dcInfoCfmYn" name="dcInfoCfmYn" type="hidden" value=""/><!-- 자동차보험 기가입자 할인안내 확인여부 -->
# <input id="planNo" name="planNo" type="hidden" value="80000028559W075"/><!-- 설계번호(from기간계) -->
# <input id="pdcDvcd" name="pdcDvcd" type="hidden" value="l_tooth"/>
# <input id="cmPynTgtClsfCd" name="cmPynTgtClsfCd" type="hidden" value=""/><!-- CM제휴대상구분코드 -->
# <input id="chdDvcd" name="chdDvcd" type="hidden" value="1"/>
# <input id="nonStopYn" name="nonStopYn" type="hidden"/> <!-- 논스톱 진행여부 -->
# <h2 class="hide_txt">본문 영역</h2>
# <div class="wrap_contents">
# <div class="plan_wrap">
# <div class="plan_btn_box">
# <a class="btn_print" href="#" onclick="javascript:gfnOpenLayer($('#popPrintLayer')); return false;">인쇄</a>
# <em class="bg_bar01"></em>
# <a class="btn_agree" href="https://www.idbins.com/inc/cYakgwanDown.jsp?FilePath=InsProduct/30581_20190401_%BE%E0%B0%FC_%B9%AB%B9%E8%B4%E7+%C7%C1%B7%CE%B9%CC%B6%F3%C0%CC%C7%C1+%B4%D9%C0%CC%B7%BA%C6%AE%C2%FC%C1%C1%C0%BA%C4%A1%BE%C6%BB%E7%B6%FB%BA%B8%C7%E81904%28CM%29.pdf" id="yakgwan" target="_blank" title="새창">약관보기</a>
# <!--
# -->
# <!--  <em class="bg_bar01 type02"></em>-->
# <!--<a href="#" class="btn_mail" onclick="javascript:gfnOpenLayer($('#popCalcSendLayer')); return false;">이메일로 받기</a>-->
# <!-- 오픈연기
#                 <a href="#" class="btn_mail" onclick="javascript:gfnOpenLayer($('#popCalcSendLayer')); return false;">이메일/문자로 받기</a>
#                 <a href="#" class="btns btn_line_gray" onclick="alert('준비중..'); return false;">
#                     <span>최근계산내역</span>
#                 </a> -->
# </div>
# <div class="plan_txt_box">
# <span class="txt_green"></span>고객님은
#                 <span class="txt_orange" id="txtPymTrm">7년간 매월 24,510원</span>을 내시면
#
#
#
#                         <span class="txt_orange" id="txtArcTrm">7년만기 자동갱신</span>을 통해 보장받습니다.
#
#
#
#
#                 <strong>플랜과 보험기간, 납입기간, 납입주기를 선택해 주세요.</strong>
# <!-- 추후 통계데이터 나오면 반영 -->
# </div>
# <!-- 마지막 플랜정보로 담보명,담보상세 출력용 -->
# <!-- s:담보리스트 -->
# <ul class="plan_select ui_plan_select">
# <li class="plan_name">
# <dl>
# <dt>
# <div>보장내용</div>
# </dt>
# <dd>
# <div name="cvrRow_0">
# <strong>치아보존치료비(상해및질병)<br/>- 아말감 또는 글래스아이노머(G.I)<br/>- 레진필링, 인레이, 온레이 등<br/>- 크라운 치료</strong>
# <a class="ico_pop" href="#" name="cvrPop_307677" title="상세설명 보기">자세히보기</a>
# </div>
# </dd>
# <dd>
# <div name="cvrRow_1">
# <strong>X-Ray및파노라마치아촬영비</strong>
# <a class="ico_pop" href="#" name="cvrPop_305031" title="상세설명 보기">자세히보기</a>
# </div>
# </dd>
# <dd>
# <div name="cvrRow_2">
# <strong>치주질환치료비</strong>
# <a class="ico_pop" href="#" name="cvrPop_305093" title="상세설명 보기">자세히보기</a>
# </div>
# </dd>
# <dd>
# <div name="cvrRow_3">
# <strong>특정치석제거(스케일링)치료비</strong>
# <a class="ico_pop" href="#" name="cvrPop_305100" title="상세설명 보기">자세히보기</a>
# </div>
# </dd>
# <dd>
# <div name="cvrRow_4">
# <strong>치아치수치료비(상해및질병)</strong>
# <a class="ico_pop" href="#" name="cvrPop_307682" title="상세설명 보기">자세히보기</a>
# </div>
# </dd>
# <dd>
# <div name="cvrRow_5">
# <strong>골절진단비(치아포함)</strong>
# <a class="ico_pop" href="#" name="cvrPop_311867" title="상세설명 보기">자세히보기</a>
# </div>
# </dd>
# <dd>
# <div name="cvrRow_6">
# <strong>어린이치과치료비(발치/영구치상실/보철/치조골이식)</strong>
# <a class="ico_pop" href="#" name="cvrPop_307667" title="상세설명 보기">자세히보기</a>
# </div>
# </dd>
# </dl>
# </li>
# <li class="plan01"> <!-- 플랜선택시 class : on -->
# <dl>
# <dt>
# <div>
# <label class="input_radio rad" for="pdcPanCd1">
# <input id="pdcPanCd1" name="pdcPanCd" onclick="calcLtmForm.selectAll(this);calcLtmForm.getCalc('default');" type="radio" value="31"/>
# <span>
# <em>실속형 <br/>
# <strong class="default" id="panSmPrm_31">
# <strong></strong>
# </strong>
# <strong class="txt_orange" id="smPrm_31" style="display:none;"></strong>
# </em>
# </span>
# </label>
# </div>
# </dt>
# <dd>
# <span class="hide_txt">치아보존치료비(상해및질병)</span>
# <ul name="cvrRow_0">
# <li class="pmoney">
# <span id="cvrInam_31_307677">20만 원<br>2만 원<br/>10만 원<br/>20만 원</br></span>
# <span id="cvr2Inam_31_307677" style="display: none">20만 원<br/>2만 원<br/>10만 원<br/>20만 원</span>
# </li>
# <li class="signup">
# <span class="on" id="cvrSign_31_307677">필수가입</span>
# </li>
# <li class="money">
# <!--첫번째 항목만 class="bubble_tip" 이후는 hide_txt-->
# <span class="bubble_tip">보험료</span>
# <span id="cvrPrm_31_307677">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt"></span>
# <ul name="cvrRow_1">
# <li class="pmoney">
#
#                                             -
#
#
#
#
#                                     </li>
# <li class="signup">
# </li>
# <li class="money">
# <span id="cvrPrm__N">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">치주질환치료비</span>
# <ul name="cvrRow_2">
# <li class="pmoney">
# <span id="cvrInam_31_305093">3만 원</span>
# <span id="cvr2Inam_31_305093" style="display: none">3만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_31_305093" onclick="javascript:calcLtmForm.setCvrCds(this, '31', '305093'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_31_305093">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt"></span>
# <ul name="cvrRow_3">
# <li class="pmoney">
#
#                                             -
#
#
#
#
#                                     </li>
# <li class="signup">
# </li>
# <li class="money">
# <span id="cvrPrm__N">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">치아치수치료비(상해및질병)</span>
# <ul name="cvrRow_4">
# <li class="pmoney">
# <span id="cvrInam_31_307682">2만 원</span>
# <span id="cvr2Inam_31_307682" style="display: none">2만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_31_307682" onclick="javascript:calcLtmForm.setCvrCds(this, '31', '307682'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_31_307682">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt"></span>
# <ul name="cvrRow_5">
# <li class="pmoney">
#
#                                             -
#
#
#
#
#                                     </li>
# <li class="signup">
# </li>
# <li class="money">
# <span id="cvrPrm__N">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt"></span>
# <ul name="cvrRow_6">
# <li class="pmoney">
#
#                                             -
#
#
#
#
#                                     </li>
# <li class="signup">
# </li>
# <li class="money">
# <span id="cvrPrm__N">
# </span>
# </li>
# </ul>
# </dd>
# </dl>
# </li>
# <li class="plan02 on"> <!-- 플랜선택시 class : on -->
# <dl>
# <dt>
# <span class="best">추천</span>
# <div>
# <label class="input_radio rad" for="pdcPanCd2">
# <input checked="checked" id="pdcPanCd2" name="pdcPanCd" onclick="calcLtmForm.selectAll(this);calcLtmForm.getCalc('default');" type="radio" value="21"/>
# <span>
# <em>일반형 <br/>
# <strong class="default" id="panSmPrm_21">
# <strong></strong>
# </strong>
# <strong class="txt_orange" id="smPrm_21" style="display:none;"></strong>
# </em>
# </span>
# </label>
# </div>
# </dt>
# <dd>
# <span class="hide_txt">치아보존치료비(상해및질병)</span>
# <ul name="cvrRow_0">
# <li class="pmoney">
# <span id="cvrInam_21_307677">30만 원<br>3만 원<br/>15만 원<br/>30만 원</br></span>
# <span id="cvr2Inam_21_307677" style="display: none">30만 원<br/>3만 원<br/>15만 원<br/>30만 원</span>
# </li>
# <li class="signup">
# <span class="on" id="cvrSign_21_307677">필수가입</span>
# </li>
# <li class="money">
# <!--첫번째 항목만 class="bubble_tip" 이후는 hide_txt-->
# <span class="bubble_tip">보험료</span>
# <span id="cvrPrm_21_307677">
#
#
#                                         16,350원</span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">X-Ray및파노라마치아촬영비</span>
# <ul name="cvrRow_1">
# <li class="pmoney">
# <span id="cvrInam_21_305031">1만 원</span>
# <span id="cvr2Inam_21_305031" style="display: none">1만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_21_305031" onclick="javascript:calcLtmForm.setCvrCds(this, '21', '305031'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_21_305031">
#
#
#                                         633원</span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">치주질환치료비</span>
# <ul name="cvrRow_2">
# <li class="pmoney">
# <span id="cvrInam_21_305093">3만 원</span>
# <span id="cvr2Inam_21_305093" style="display: none">3만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_21_305093" onclick="javascript:calcLtmForm.setCvrCds(this, '21', '305093'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_21_305093">
#
#
#                                         57원</span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">특정치석제거(스케일링)치료비</span>
# <ul name="cvrRow_3">
# <li class="pmoney">
# <span id="cvrInam_21_305100">1만 원</span>
# <span id="cvr2Inam_21_305100" style="display: none">1만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_21_305100" onclick="javascript:calcLtmForm.setCvrCds(this, '21', '305100'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_21_305100">
#
#
#                                         163원</span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">치아치수치료비(상해및질병)</span>
# <ul name="cvrRow_4">
# <li class="pmoney">
# <span id="cvrInam_21_307682">2만 원</span>
# <span id="cvr2Inam_21_307682" style="display: none">2만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_21_307682" onclick="javascript:calcLtmForm.setCvrCds(this, '21', '307682'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_21_307682">
#
#
#                                         614원</span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt"></span>
# <ul name="cvrRow_5">
# <li class="pmoney">
#
#                                             -
#
#
#
#
#                                     </li>
# <li class="signup">
# </li>
# <li class="money">
# <span id="cvrPrm__N">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">어린이치과치료비(발치/영구치상실/보철/치조골이식)</span>
# <ul name="cvrRow_6">
# <li class="pmoney">
# <span id="cvrInam_21_307667">100만 원</span>
# <span id="cvr2Inam_21_307667" style="display: none">100만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_21_307667" onclick="javascript:calcLtmForm.setCvrCds(this, '21', '307667'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_21_307667">
#
#
#                                         2,610원</span>
# </li>
# </ul>
# </dd>
# </dl>
# </li>
# <li class="plan03"> <!-- 플랜선택시 class : on -->
# <dl>
# <dt>
# <div>
# <label class="input_radio rad" for="pdcPanCd3">
# <input id="pdcPanCd3" name="pdcPanCd" onclick="calcLtmForm.selectAll(this);calcLtmForm.getCalc('default');" type="radio" value="11"/>
# <span>
# <em>고급형 <br/>
# <strong class="default" id="panSmPrm_11">
# <strong></strong>
# </strong>
# <strong class="txt_orange" id="smPrm_11" style="display:none;"></strong>
# </em>
# </span>
# </label>
# </div>
# </dt>
# <dd>
# <span class="hide_txt">치아보존치료비(상해및질병)</span>
# <ul name="cvrRow_0">
# <li class="pmoney">
# <span id="cvrInam_11_307677">40만 원<br>4만 원<br/>20만 원<br/>40만 원</br></span>
# <span id="cvr2Inam_11_307677" style="display: none">40만 원<br/>4만 원<br/>20만 원<br/>40만 원</span>
# </li>
# <li class="signup">
# <span class="on" id="cvrSign_11_307677">필수가입</span>
# </li>
# <li class="money">
# <!--첫번째 항목만 class="bubble_tip" 이후는 hide_txt-->
# <span class="bubble_tip">보험료</span>
# <span id="cvrPrm_11_307677">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">X-Ray및파노라마치아촬영비</span>
# <ul name="cvrRow_1">
# <li class="pmoney">
# <span id="cvrInam_11_305031">1만 원</span>
# <span id="cvr2Inam_11_305031" style="display: none">1만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_11_305031" onclick="javascript:calcLtmForm.setCvrCds(this, '11', '305031'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_11_305031">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">치주질환치료비</span>
# <ul name="cvrRow_2">
# <li class="pmoney">
# <span id="cvrInam_11_305093">3만 원</span>
# <span id="cvr2Inam_11_305093" style="display: none">3만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_11_305093" onclick="javascript:calcLtmForm.setCvrCds(this, '11', '305093'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_11_305093">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">특정치석제거(스케일링)치료비</span>
# <ul name="cvrRow_3">
# <li class="pmoney">
# <span id="cvrInam_11_305100">1만 원</span>
# <span id="cvr2Inam_11_305100" style="display: none">1만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_11_305100" onclick="javascript:calcLtmForm.setCvrCds(this, '11', '305100'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_11_305100">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">치아치수치료비(상해및질병)</span>
# <ul name="cvrRow_4">
# <li class="pmoney">
# <span id="cvrInam_11_307682">4만 원</span>
# <span id="cvr2Inam_11_307682" style="display: none">4만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_11_307682" onclick="javascript:calcLtmForm.setCvrCds(this, '11', '307682'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_11_307682">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">골절진단비(치아포함)</span>
# <ul name="cvrRow_5">
# <li class="pmoney">
# <span id="cvrInam_11_311867">30만 원</span>
# <span id="cvr2Inam_11_311867" style="display: none">30만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_11_311867" onclick="javascript:calcLtmForm.setCvrCds(this, '11', '311867'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_11_311867">
# </span>
# </li>
# </ul>
# </dd>
# <dd>
# <span class="hide_txt">어린이치과치료비(발치/영구치상실/보철/치조골이식)</span>
# <ul name="cvrRow_6">
# <li class="pmoney">
# <span id="cvrInam_11_307667">100만 원</span>
# <span id="cvr2Inam_11_307667" style="display: none">100만 원</span>
# </li>
# <li class="signup">
# <a class="signup_box on" href="#" id="cvrSign_11_307667" onclick="javascript:calcLtmForm.setCvrCds(this, '11', '307667'); return false;">
# <span class="signup_ball">
# <em class="hide_txt">ON</em>
# </span>
# </a>
# </li>
# <li class="money">
# <span id="cvrPrm_11_307667">
# </span>
# </li>
# </ul>
# </dd>
# </dl>
# </li>
# </ul>
# <!-- e:담보리스트 -->
# <!-- s:선택한 담보 상세 내용 (클릭시 plan_tip_wrap display:block; )-->
# <!--
#             <a href="#" class="btn_plan_guide ui_plan_guide">
#                 <span class="ico_note">선택하신 보장내용을 쉽게 확인하세요
#                     <em></em>
#                     <span class="hide_txt">열기</span>
#                 </span>
#             </a>
#             <div id="dest_tip" class="plan_tip_wrap">
#             </div> -->
# <!-- e:선택한 담보 상세 내용 -->
# <!-- e:선택한 담보 상세 내용 copy 용-->
# <!--
#             <div style="display:none;">
#                 <ul id="org_tip" class="plan_tip_list clfix">
#
#                         <li id="ico_plan307677" class="nth02">
#                             <dl class="ico_plan307677">
#                                 <dt>
#                                     <em>
#
#                                     </em>
#                                     <strong>치아보존치료비(상해및질병)</strong>
#                                 </dt>
#                                 <dd>피보험자가 보장개시일(질병은 계약일로부터 90일이 지난날의 다음날, 상해는 계약일) 이후 약관에서 정한 질병 또는 상해로 유치 및 영구치에 아말감, 글래스아이노머로 충전치료시 가입금액 10%, 아말감, 글래스아이노머 이외로 충전치료시 50%, 크라운(연간 3개한도)치료시 100% 지급(단, 최초계약일로부터 1년미만 기간에 질병으로 유치 및 영구치 보존치료를 받은 경우 위 보장금액의 50%만 지급)</dd>
#                             </dl>
#                         </li>
#
#                         <li id="ico_plan305031" class="nth02">
#                             <dl class="ico_plan305031">
#                                 <dt>
#                                     <em>
#
#                                     </em>
#                                     <strong>X-Ray및파노라마치아촬영비</strong>
#                                 </dt>
#                                 <dd>피보험자가 보장개시일(질병은 계약일로부터 90일이 지난날의 다음날, 상해는 계약일) 이후 상해 또는 질병을 직접적인 원인으로 의료법 제3조(의료기관)에서 정한 치과 병, 의원 또는 이와 동등하다고 회사가 인정하는 의료기관에서 X-ray 촬영 또는 파노라마 촬영을 한 경우에는 각각의 촬영 1회당 보험가입금액을 지급</dd>
#                             </dl>
#                         </li>
#
#                         <li id="ico_plan305093" class="nth02">
#                             <dl class="ico_plan305093">
#                                 <dt>
#                                     <em>
#
#                                     </em>
#                                     <strong>치주질환치료비</strong>
#                                 </dt>
#                                 <dd>피보험자가 보장개시일(계약일로부터 90일이 지난날의 다음날) 이후 국민건강보험법에서 정한 보험급여 또는 의료급여법에서 정한 의료급여에서 치주질환(잇몸질환)치료가 필요하다고 인정되는 기준에 해당하는 치료를 받은 경우 보험가입금액을 지급</dd>
#                             </dl>
#                         </li>
#
#                         <li id="ico_plan305100" class="nth02">
#                             <dl class="ico_plan305100">
#                                 <dt>
#                                     <em>
#
#                                     </em>
#                                     <strong>특정치석제거(스케일링)치료비</strong>
#                                 </dt>
#                                 <dd>피보험자가 보장개시일(계약일로부터 90일이 지난날의 다음날) 이후 치석제거(스케일링) 치료를 진단 확정 받고 의료법 제3조(의료기관)에서 정한 치과 병, 의원 또는 이와 동등하다고 회사가 인정하는 의료기관에서 치석제거(스케일링) 치료를 받은 경우 보험가입금액을 지급(연간 1회한도)</dd>
#                             </dl>
#                         </li>
#
#                         <li id="ico_plan307682" class="nth02">
#                             <dl class="ico_plan307682">
#                                 <dt>
#                                     <em>
#
#                                     </em>
#                                     <strong>치아치수치료비(상해및질병)</strong>
#                                 </dt>
#                                 <dd>피보험자가 보장개시일(질병은 계약일로부터 90일이 지난날의 다음날, 상해는 계약일) 이후 약관에서 정한 질병 또는 상해로 유치 및 영구치 손상에 대한 진단을 받고 해당 유치 및 영구치에 치수치료를 받은 경우 치아 1개당 가입금액 100%를 지급(단, 최초계약일로부터 1년미만 기간에 질병으로 유치 및 영구치 치수치료를 받은 경우 위 보장금액의 50% 지급)</dd>
#                             </dl>
#                         </li>
#
#                         <li id="ico_plan311867" class="nth02">
#                             <dl class="ico_plan311867">
#                                 <dt>
#                                     <em>
#
#                                     </em>
#                                     <strong>골절진단비(치아포함)</strong>
#                                 </dt>
#                                 <dd>피보험자가 보험기간 중 상해사고로 골절진단(치아파절 포함)을 받은 경우 가입금액을 지급(1사고당)</dd>
#                             </dl>
#                         </li>
#
#                         <li id="ico_plan307667" class="nth02">
#                             <dl class="ico_plan307667">
#                                 <dt>
#                                     <em>
#
#                                     </em>
#                                     <strong>어린이치과치료비(발치/영구치상실/보철/치조골이식)</strong>
#                                 </dt>
#                                 <dd>- 피보험자가 보험기간 중 상해 또는 질병을 직접적인 원인으로 약관에서 정한 발치치료를 받은 경우 단순발치 치료시 가입금액 0.5%, 정교한발치 치료시 1%, 완전 매복된 치아의 발치 치료시 가입금액 2% 를 지급
# - 피보험자가 보험기간중 보장개시일(질병은 계약일로부터 90일이 지난날의 다음날, 상해는 계약일) 이후 약관에서 정한 질병 또는 상해로 영구치 발거를 진단 확정받고, 해당 영구치를 발거한 경우 영구치 1개당 가입금액의 10%, 영구치를 발거한 부위에 틀니(연간1회한도), 임플란트 치료시 영구치 발거 1개당 가입금액 100%, 브릿지 치료시 영구치 발거 1개당 가입금액 50%, 임플란트 시술을 받기 위해 특정 임플란트 치조골이식술 치료를 받은 경우 영구치발거 1개당 가입금액의 20%를 지급합니다. 다만 특정 임플란트 치조골이식술 치료의 경우 임플란트 시술을 받은 경우에 한하여 보험금을 지급합니다.(단, 최초계약일로부터 2년미만 기간에 질병으로 영구치 발거 후 치아보철치료 및 특정임플란트 치조골이식술 치료를 받은 경우 상기 금액의 50% 지급)</dd>
#                             </dl>
#                         </li>
#
#                 </ul>
#             </div>
#              -->
# <!-- e:선택한 담보 상세 내용 -->
# </div>
# <!-- s: -->
# <div class="plan_total ui_plan_slider">
# <!--선택 갯수에 따라 2개일때 plan_num02 ~ 6개일때 plan_num06까지-->
# <input id="arcTrmCd" name="arcTrmCd" type="hidden" value="Y007"/>
# <dl class="plan_bot_dl ui_plan01 plan_num03">
# <dt>보험기간</dt>
# <dd>
# <div class="plan_slide_box">
# <div class="slide_bar"></div>
# <a class="year01" href="#" id="selArcTrm1" name="selArcTrm" onclick="calcLtmForm.setTerm(this, 'arcTrm'); return false;" value="Y007">7년</a>
# <a class="year02" href="#" id="selArcTrm2" name="selArcTrm" onclick="calcLtmForm.setTerm(this, 'arcTrm'); return false;" value="Y015">15년</a>
# <a class="year03" href="#" id="selArcTrm3" name="selArcTrm" onclick="calcLtmForm.setTerm(this, 'arcTrm'); return false;" value="Y020">20년</a>
# </div>
# </dd>
# </dl>
# <!--선택 갯수에 따라 2개일때 plan_num02 ~ 6개일때 plan_num06까지-->
# <!-- 주택화재보험 납입기간은 항상 보험기간과 같음 + 오토바이운전자 + 치아보험 -->
# <dl class="plan_bot_dl ui_plan02 ui_disable plan_num03">
# <input id="pymTrmCd" name="pymTrmCd" type="hidden" value="Y007"/>
# <dt>납입기간</dt>
# <dd>
# <div class="plan_slide_box">
# <!--보험 기간에 따라 disable 처리 class-->
# <div class="slide_bar">
# <span class="disable_bar" style="width:40%"></span>
# </div>
# <a class="year01" href="#" id="selPymTrm1" name="selPymTrm" onclick="calcLtmForm.setTerm(this, 'pymTrm'); return false;" value="Y007">7년</a>
# <a class="year02" href="#" id="selPymTrm2" name="selPymTrm" onclick="calcLtmForm.setTerm(this, 'pymTrm'); return false;" value="Y015">15년</a>
# <a class="year03" href="#" id="selPymTrm3" name="selPymTrm" onclick="calcLtmForm.setTerm(this, 'pymTrm'); return false;" value="Y020">20년</a>
# </div>
# </dd>
# </dl>
# <!--e:ux_modify 20160211 기간 선택 코딩 변경-->
# <dl class="plan_bot_dl last">
# <dt>납입주기</dt>
# <dd>
# <ul class="label_horizental clfix">
# <li>
# <label class="input_radio rad" for="pymMtdCd1 ">
# <input checked="checked" id="pymMtdCd1" name="pymMtdCd" onclick="calcLtmForm.setAgain();" type="radio" value="01"/>
# <span><em>월납</em></span>
# </label>
# </li>
# <li>
# <label class="input_radio rad" for="pymMtdCd2 ">
# <input id="pymMtdCd2" name="pymMtdCd" onclick="calcLtmForm.setAgain();" type="radio" value="05"/>
# <span><em>연납</em></span>
# </label>
# </li>
# </ul>
# </dd>
# </dl>
# <!-- s: -->
# <div class="right_plan" display:none;="">
# <!-- 2016.03.08 다이렉트 할인율 : 대용상품 기간계 산출이 어려워 문구 숨김
#                 <dl class="plan_dc">
#                     <dt>
#                         <span>DB손해보험 동일상품 대비</span>
#                         <strong class="txt_orange">다이렉트 할인율
#                             <strong>15%</strong>
#                         </strong>
#                     </dt>
#                     <dd>
#                         <a href="#" class="btns btn_line_gray_s q_tip33"><span>할인금액보기</span></a>
#                     </dd>
#                 </dl>
#                 -->
# <dl class="plan_money">
# <dt>
# <span id="totPrmPymMtdTxt">월 보험료</span>
# <strong class="txt_green"><strong id="totPrm">24,510</strong>원</strong>
# </dt>
# <dd>
# <strong>예상만기환급률
#                             <strong class="txt_orange" id="expRtrnRate">14.7%</strong>
# </strong>
# <a class="btns btn_line_gray_s" href="#" onclick="javascript: exCancelForm.doSrch(); return false;">
# <span>해지환급금 예시</span>
# </a>
# </dd>
# </dl>
# </div>
# <!-- e: -->
# <!--s:다시 계산 영역-->
# <div class="right_plan_again" display:none;="">
# <div class="arrow_txt">변경정보를 모두 선택한 후<br/>다시 계산 버튼을 클릭해 주세요.</div>
# <a class="btns btn_all_agree_whit on" href="#" onclick="javascript: calcLtmForm.getCalc('calcSave'); return false;">
# <em class="ico ico_again"></em>
# <span>다시 계산</span>
# </a>
# </div>
# <!--e:다시 계산 영역-->
# </div>
# <div class="btn_foot mgt16">
# <a class="btns btn_pre" href="#" onclick="javascript: calcLtmForm.goPrev(); return false;">
# <em class="ico ico_pre"></em>
# <span>이전</span>
# </a>
# <a class="btns btn_next" href="#" onclick="javascript: calcLtmForm.goNext('after'); emfConvCall(581, 3466, 0, 0, 0); gaCall('pc_step3'); return false;">
# <span>다음</span>
# <em class="ico ico_next"></em>
# </a>
# </div>
# <!-- s:ux_modify 20160117 tooltip 추가-->
# <!--담보설명 툴팁 화살표 위치 class로 제어 tl, tc, tr, bl, bc, br-->
# <div class="tooltip_box plan_type02 bc a_tip01">
# <div class="tool_cont">
# <strong class="tip_tit">치아보존치료비(상해및질병)</strong>
# <ul class="dot_ulli last">담보상세설명으로 대체 </ul>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <div class="tooltip_box plan_type02 bc a_tip02">
# <div class="tool_cont">
# <strong class="tip_tit">X-Ray및파노라마치아촬영비</strong>
# <ul class="dot_ulli last">담보상세설명으로 대체 </ul>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <div class="tooltip_box plan_type02 bc a_tip03">
# <div class="tool_cont">
# <strong class="tip_tit">치주질환치료비</strong>
# <ul class="dot_ulli last">담보상세설명으로 대체 </ul>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <div class="tooltip_box plan_type02 bc a_tip04">
# <div class="tool_cont">
# <strong class="tip_tit">특정치석제거(스케일링)치료비</strong>
# <ul class="dot_ulli last">담보상세설명으로 대체 </ul>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <div class="tooltip_box plan_type02 bc a_tip05">
# <div class="tool_cont">
# <strong class="tip_tit">치아치수치료비(상해및질병)</strong>
# <ul class="dot_ulli last">담보상세설명으로 대체 </ul>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <div class="tooltip_box plan_type02 bc a_tip06">
# <div class="tool_cont">
# <strong class="tip_tit">골절진단비(치아포함)</strong>
# <ul class="dot_ulli last">담보상세설명으로 대체 </ul>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <div class="tooltip_box plan_type02 bc a_tip07">
# <div class="tool_cont">
# <strong class="tip_tit">어린이치과치료비(발치/영구치상실/보철/치조골이식)</strong>
# <ul class="dot_ulli last">담보상세설명으로 대체 </ul>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <!-- e:ux_modify 20160117 tooltip 추가-->
# <!-- s: 할인보험료 설명 툴팁-->
# <div class="tooltip_box plan_type01 a_tip33">
# <div class="tool_cont">
# <dl class="plan_tool_dl">
# <dt>할인금액 보기</dt>
# <dd class="dc_plan_cont">
# <strong>DB손해보험 동일상품 대비</strong>
# <strong class="b_txt">다이렉트 할인 보험료(매월)</strong>
# <div class="money">
# <strong>2,500</strong>
# <span>원</span>
# </div>
# </dd>
# <dd>
# <span class="tip_txt">- 보장보험료(적립보험료 제외) 부분에 할인 적용됩니다.</span>
# </dd>
# </dl>
# </div>
# <a class="btn_tool_close" href="#">
# <span class="hide_txt">툴팁 닫기</span>
# </a>
# <span class="tip_arrow"></span>
# </div>
# <!-- e: 할인보험료 설명 툴팁 -->
# </div>
# <!-- e:contents영역  -->
# <div>
# <!--
#     <div>
#     <table>
#         <tr>
#             <td>보험기간</td>
#             <td>
#
#                     <label><input id="arcTrmCd1" name="arcTrmCd" title="7년" onclick="javascript:calcLtmForm.setAgain();" type="radio" value="Y007" checked="checked"/>7년</label>
#
#
#
#
#                     <label><input id="arcTrmCd2" name="arcTrmCd" title="15년" onclick="javascript:calcLtmForm.setAgain();" type="radio" value="Y015"/>15년</label>
#
#
#
#
#                     <label><input id="arcTrmCd3" name="arcTrmCd" title="20년" onclick="javascript:calcLtmForm.setAgain();" type="radio" value="Y020"/>20년</label>
#
#
#
#         </td>
#         </tr>
#         <tr>
#             <td>납입기간</td>
#             <td>
#
#                         <label><input id="pymTrmCd1" name="pymTrmCd" title="7년" onclick="javascript:calcLtmForm.setAgain();" type="radio" value="Y007" checked="checked"/>7년</label>
#
#
#
#
#                         <label><input id="pymTrmCd2" name="pymTrmCd" title="15년" onclick="javascript:calcLtmForm.setAgain();" type="radio" value="Y015"/>15년</label>
#
#
#
#
#                         <label><input id="pymTrmCd3" name="pymTrmCd" title="20년" onclick="javascript:calcLtmForm.setAgain();" type="radio" value="Y020"/>20년</label>
#
#
#
#         </td>
#
#         <tr></tr>
#     </table>
#     </div>
#  -->
# </div>
# <div>
# <input name="_csrf" type="hidden" value="0887e990-252c-4ac6-9b29-aa5c627b36b4"/>
# </div></input></input></input></input></input></form>
# <div class="wrap_popup" id="popJoinBeforLayer" style="display: none;">
# <div class="dimm" style="display:block"></div>
# <div class="wrap_container w980">
# <div class="wrap_pop">
# <div class="wrap_pop_head">
# <h1>가입 전 확인사항</h1>
# </div>
# <div class="wrap_cont_sc">
# <div class="wrap_pop_cont">
# <ul class="join_befor_list long clfix">
# <li>
# <em class="ico ico_shield"></em>
# <div class="wrap_tit">
# <span class="txt_green">공인인증서</span> 없이도
#                                         <br/>가입할 수 있어요.</div>
# <div class="wrap_txt">DB손해보험 다이렉트 보험 가입 시,
#                                         <br/>공인인증서뿐만 아니라
#                                         <br/>카카오페이 인증으로도
#                                         <br/>가입할 수 있습니다.
#                                         <br/>(일부 보험상품 제외)</div>
# </li>
# <li>
# <em class="ico ico_card03"></em>
# <div class="wrap_tit">
# <span class="txt_green">실시간 출금</span>을
# 										<br/> 선택하시면 더 편리합니다.</div>
# <div class="wrap_txt">선택하신 보험상품은 정기적으로
# 										<br/>보험료를 납입하는 상품입니다.
# 										<br/> 최초 보험료를 실시간 출금으로 결제하시고
# 										<br/>동일한 계좌에서 이후의 보험료가
# 										<br/>납입되도록 설정하시면
# 										<br/>계좌번호를 두 번 입력하는
# 										<br/>번거로움을 줄일 수 있습니다.</div>
# </li>
# <li>
# <em class="ico ico_letter"></em>
# <div class="wrap_tit">
# <span class="txt_green">보험증권</span>은
# 										<br/> 휴대폰과 이메일로 받으실 수 있습니다.</div>
# <div class="wrap_txt">보험가입이 완료되면
# 										<br/>소지하신 휴대폰이나 이메일로
# 										<br/>가입을 확인하실 수 있습니다.
# 										<br/> (증권수령 방식을
# 										<br/>‘휴대폰/이메일’로 선택하신 경우)
# 										<br/>홈페이지의 마이페이지에서도
# 										<br/>계약내용을 확인할 수 있으며
# 										<br/>증명서 출력이 가능합니다.</div>
# </li>
# </ul>
# <div class="btn_right btn_join_befor">
# <a class="btns btn_pop_green" href="#" onclick="javascript: calcLtmForm.goNext('after'); return false;"></a>
# <span>다음단계</span>
# <em class="ico ico_arw"></em>
# </div></div></div></div></div></div></div></div></div></body></html>
#
#
#
# <div class="wrap_pop_foot">
# <a class="btn_pop_close" href="#" onclick="javascript:gfnCloseLayer($('#popJoinBeforLayer')); return false;">
# <em class="hide_txt">닫기</em>
# </a>
# </div>
#
#
# <!-- 가입전 확인사항 안내 팝업 -->
# <div class="wrap_popup" id="popDiscountInfoLayer" style="display:none;">
# <div class="dimm" style="display:block"></div>
# <div class="wrap_container w600">
# <div class="wrap_pop">
# <div class="wrap_pop_head">
# <h1>알려드립니다</h1>
# </div>
# <div class="wrap_cont_sc">
# <div class="wrap_pop_cont">
# <div class="box_info_discount">
# <div class="ico_discount"></div>
# <div class="tit">안녕하세요.
# 							<strong class="txt_green">DB손해보험 자동차보험 고객님</strong>
# </div>
# <p>매월 다이렉트로 저렴한 보험료는 기본!
# 							<br/>자동차보험 가입고객님은
# 							<strong class="txt_orange">1회차 보험료 12% 추가 할인</strong>됩니다.</p>
# </div>
# <div class="btn_center bd_top">
# <a class="btns btn_pop_green" href="#" onclick="javascript:$('#dcInfoCfmYn').val(1); gfnCloseLayer($('#popDiscountInfoLayer')); return false;">
# <span>확인</span>
# </a>
# </div>
# </div>
# </div>
# <div class="wrap_pop_foot">
# <a class="btn_pop_close" href="#" onclick="javascript:gfnCloseLayer($('#popDiscountInfoLayer')); return false;">
# <em class="hide_txt">닫기</em>
# </a>
# </div>
# </div>
# </div>
# </div><!-- 자동차보험기가입자 할인 안내 팝업 -->
# ...
# <div id="wp_tg_cts" style="display:none;"></div>
# <script type="text/javascript">
# 	try {
# 		var wptg_tagscript_vars = wptg_tagscript_vars || [];
# 		wptg_tagscript_vars.push(
# 		(function() {
# 			return {
# 				wp_hcuid:"",   /*Cross device targeting을 원하는 광고주는 로그인한 사용자의 Unique ID (ex. 로그인 ID, 고객넘버 등)를 암호화하여 대입.
# 						*주의: 로그인 하지 않은 사용자는 어떠한 값도 대입하지 않습니다.*/
# 				ti:"25896",	/*광고주 코드*/
# 				ty:"Home",	/*트래킹태그 타입*/
# 				device:"web"	/*디바이스 종류 (web 또는 mobile)*/
#
# 			};
# 		}));
# 	}
#     catch(e) {
#         LOG("===========타겟팅게이츠 통합스크립트 Error!!===================");
#         LOG(e);
#     }
# 	</script>
# <script async="" src="//cdn-aitg.widerplanet.com/js/wp_astg_4.0.js" type="text/javascript"></script>
# <!-- // WIDERPLANET  SCRIPT END 2017.4.29 -->
# <!-- 블레이드 스크립트 삽입 공통 -->
# <script class="microad_blade_track" type="text/javascript">
# 	try {
# 		var microad_blade_gl = microad_blade_gl || { 'params' : new Array(), 'complete_map' : new Object() };
# 		(function() {
# 		var param = {'co_account_id' : '16635', 'group_id' : '', 'country_id' : '11', 'ver' : '2.1.0'};
# 		microad_blade_gl.params.push(param);
#
# 		var src = (location.protocol == 'https:')
# 		? 'https://d-cache.microadinc.com/js/blade_track_gl.js' : 'http://d-cache.microadinc.com/js/blade_track_gl.js';
#
# 		var bs = document.createElement('script');
# 		bs.type = 'text/javascript'; bs.async = true;
# 		bs.charset = 'utf-8'; bs.src = src;
#
# 		var s = document.getElementsByTagName('script')[0];
# 		s.parentNode.insertBefore(bs, s);
# 		})();
# 	}
#     catch(e) {
#         LOG("===========블레이드 통합스크립트 Error!!===================");
#         LOG(e);
#     }
# 	</script>
# <!-- 블레이드 스크립트 삽입 공통 -->
# <!-- AceClick WebSite Gathering Script V0.91.20170523 삽입 공통 -->
# <script type="text/Javascript">
# 	try {
# 		if(typeof(AMRS_GC)=='undefined'){
# 		var AMRS_O=[];var AMRS_CK = new Image();var AMRS_GC='AG4A385211163';var AMRS_GD='mrsg.aceclick.co.kr';var AMRS_GP='8080';var AMRS_TI=(new Date()).getTime();
# 		var AMRS_PR = location.protocol=="https:"?"https://"+AMRS_GD+":843":"http://"+AMRS_GD+":"+AMRS_GP; AMRS_CK.src = AMRS_PR+'/?cookie';
# 		if(typeof(Array.prototype.push)!='undefined'){ AMRS_O.push(AMRS_CK);}
# 		var _AMSC = document.createElement('script');var _AMSM = document.getElementsByTagName('script')[0];_AMSC.src=(location.protocol.indexOf('http') == 0 ? location.protocol : 'http:') + '//mrss.aceclick.co.kr/aceclick.js?rt='+AMRS_TI;_AMSM.parentNode.insertBefore(_AMSC, _AMSM);
# 		}
# 	}
#     catch(e) {
#         LOG("===========AceClick 통합스크립트 Error!!===================");
#         LOG(e);
#     }
# 	</script>
# <!-- AceClick WebSite Gathering Script End V0.91.20170523 삽입 공통 -->
# <!-- EDN+ 리타겟팅 공통스크립트 -->
# <iframe frameborder="0" height="0" id="hfrADCheck" scrolling="no" src="//adcheck.about.co.kr/mad/prd/view?shopid=directdongbu" style="display:none;" width="0"></iframe>
# <!-- EDN+ 리타겟팅 공통스크립트 -->
# <!-- 인터웍스 PC 리타겟팅 공통스크립트 -->
# <script type="text/javascript">
# 	/* <![CDATA[ */
# 	var iwm_ads_id='dongbu',iwm_ads_label='*global';
# 	/* ]]> */
# 	</script>
# <script src="//interface.interworksmedia.co.kr/js/conversion.min.js" type="text/javascript"></script>
# <!-- 인터웍스 PC 리타겟팅 공통스크립트 -->
# <!-- Facebook Pixel Code-->
# <script>
# 	try {
# 		!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 		n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# 		n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# 		document,'script','https://connect.facebook.net/en_US/fbevents.js');
# 		fbq('init', '1954240851466067'); // Insert your pixel ID here.
# 		fbq('track', 'PageView');
# 	}
#     catch(e) {
#         LOG("===========Facebook Pixel Code 통합스크립트 Error!!===================");
#         LOG(e);
#     }
# 	</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1954240851466067&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- DO NOT MODIFY -->
# <!-- End Facebook Pixel Code -->
# <!-- 구글(애널리틱스) -->
# <!-- 구글(애널리틱스) -->
# <!-- Global site tag (gtag.js) - Google AdWords: 815363353 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-815363353"></script>
# <script>
#     try {
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'AW-815363353');
#     }
#     catch(e) {
#         LOG("===========Google AdWords Script Error!!===================");
#         LOG(e);
#     }
#     </script>
# <!-- Global site tag (gtag.js) - Google AdWords: 815363353 End -->
# <!-- 카카오광고 픽셀 -->
# <script charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script>
# <script type="text/javascript">
#     try {
#         $(document).ready(function () {
#             var thisUrl = document.location.pathname;
#             LOG("commonAdwebScript_thisUrl_kakaoPixel===>" + thisUrl);
#             if(thisUrl=='/product/at/pvuatarc/step1/formStepPre.do') {
#                 kakaoPixel('1045042695096415663').pageView('info_insert');
#             }else if(thisUrl=='/product/at/pvuatarc/step1/procStep1SlfCtf.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('info_agree');
#                 });
#             }else if(thisUrl=='/product/at/pvuatarc/step2/movepage.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('identity_verifi');
#                 });
#             }else if(thisUrl=='/product/at/pvuatarc/step2/scrCarSelect.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('carinfo_number');
#                 });
#             }else if(thisUrl=='/product/at/pvuatarc/step2/scrCarType.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('carinfo_categor');
#                 });
#             }else if(thisUrl=='/product/at/pvuatarc/step2/scrCarInfoSedan.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('carinfo_special');
#                 });
#             }else if(thisUrl=='/product/at/pvuatarc/step3/step3Move.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('rider_range');
#                 });
#             }else if(thisUrl=='/product/at/pvuatarc/step4/step4Move.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('carinsu_calc');
#                 });
#             }else if(thisUrl=='/product/at/pvuatarc/step7/step7PayForm.do') {
#                 $('a.btn_next').on('click', function () {
#                     kakaoPixel('1045042695096415663').pageView('insu_complete');
#                 });
#             }else{
#                 kakaoPixel('1045042695096415663').pageView(); // 기본
#             }
#         });
#     }
#     catch(e) {
#         LOG("===========카카오광고 픽셀 Script Error!!===================");
#         LOG(e);
#     }
#     </script>
# <!-- 카카오광고 픽셀 End -->
# <!-- Facebook Pixel Code -->
# <script>
#      try {
#          !function(f,b,e,v,n,t,s)
#          {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#          n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#          if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#          n.queue=[];t=b.createElement(e);t.async=!0;
#          t.src=v;s=b.getElementsByTagName(e)[0];
#          s.parentNode.insertBefore(t,s)}(window, document,'script','https://connect.facebook.net/en_US/fbevents.js');
#          fbq('init', '343547753167407');
#          fbq('track', 'PageView');
#          $(document).ready(function () {
#              var thisUrl = document.location.pathname;
#              LOG("commonAdwebScript_thisUrl_Facebook===>" + thisUrl);
#              if(thisUrl=='/product/at/pvuatarc/step1/formStepPre.do') {
#                  fbq('track', 'Search');
#              }else if(thisUrl=='/product/at/pvuatarc/step1/procStep1SlfCtf.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'viewcontent');
#                  });
#              }else if(thisUrl=='/product/at/pvuatarc/step2/movepage.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'addtocart');
#                  });
#              }else if(thisUrl=='/product/at/pvuatarc/step2/scrCarSelect.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'addtowishlist');
#                  });
#              }else if(thisUrl=='/product/at/pvuatarc/step2/scrCarType.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'initiatecheckout');
#                  });
#              }else if(thisUrl=='/product/at/pvuatarc/step2/scrCarInfoSedan.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'addpaymentinfo');
#                  });
#              }else if(thisUrl=='/product/at/pvuatarc/step3/step3Move.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'purchase');
#                  });
#              }else if(thisUrl=='/product/at/pvuatarc/step4/step4Move.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'lead');
#                  });
#              }else if(thisUrl=='/product/at/pvuatarc/step7/step7PayForm.do') {
#                  $('a.btn_next').on('click', function () {
#                      fbq('track', 'completeregistration');
#                  });
#              }else{
#                  fbq('track', 'PageView'); // 기본
#              }
#          });
#      }
#      catch(e) {
#          LOG("===========Facebook Pixel Code 통합스크립트_20190213 Error!!===================");
#          LOG(e);
#      }
#      </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=343547753167407&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Start Script for IFDO -->
# <script type="text/javascript">
#     try {
#         var _NB_gs = 'wlog.ifdo.co.kr';
#         var _NB_MKTCD = 'NIA119027277';
#         var _NB_APPVER=''; /* 하이브리드 앱 버전 */
#         (function(a,b,c,d,e){
#             var f=b.createElement(c);
#             var g=b.getElementsByTagName(c)[0];
#             f.async=1;
#             f.src=d;
#         f.setAttribute('charset','utf-8');
#         g.parentNode.insertBefore(f,g)})(window,document,'script','//script.ifdo.co.kr/jfullscript.js');
#     }
#     catch(e) {
#         LOG("===========IFDO 통합스크립트 Error!!===================");
#         LOG(e);
#     }
#     </script>
# <!-- End Script for IFDO -->
# <!-- DMP ROAS Script :: Common Start -->
# <script type="text/javascript">
# 	try {
# 	    var DMPSV = DMPSV || [];
# 	    DMPSV['SiteId'] = 'ff2989';
#
# 	    (function (w, d, s, url) {
# 	        var e = d.createElement(s);
# 	        var t = d.getElementsByTagName(s)[0];
# 	        e.async = 1;
# 	        e.src = url + '?' + new Date().getTime();
# 	        e.setAttribute('charset', 'utf-8');
# 	        t.parentNode.insertBefore(e, t)
# 	    })(window, document, 'script', '//tracking.a-bidding.com/js/dmp_roas_simple.min.js');
# 	}
#     catch(e) {
#         LOG("===========랭키로하스 통합스크립트 Error!!===================");
#         LOG(e);
#     }
# 	</script>
# <!-- DMP ROAS Script :: Common End -->
#
#
#
#
#     <!-- ADN Tracker[공통] start -->
# <script type="text/javascript">
#     try {
#         var adn_param = adn_param || [];
#         adn_param.push([{
#          ui:'100546',
#          ut:'Home'
#         }]);
#     }
#     catch(e) {
#         LOG("===========클로징패널 공통스크립트 Error!!===================");
#         LOG(e);
#     }
#     </script>
# <script async="" src="//fin.rainbownine.net/js/adn_tags_1.0.0.js" type="text/javascript"></script>
# <!-- ADN Tracker[공통] end -->
#
# <script id="ULR4snxsdsTr" type="text/javascript">//<![CDATA[
# (function (){var Rx = "ULR4snxsdsTr",bN = function(e){return e.replace(/ |'|"|\+|&|\?|\r|\n|\t|;|\(|\)|\{|\}/g,"").replace(/c/g,"ld");},W5 = "tAgOVjCwPf1N.ext.jsp",S_ = "/vestweb/error_pop.jsp",i2 = "/vestweb/error_lay.html",xS = 0,Ul = 0,XK = 1,z9 = ['*.test.com'],V$ = ['*.yettiesoft.com'],aE = null,DD=[{'pH':['*'],'QP':[{'Xa':{'B9':['CnslaplyForm.save','PrnifOferCsn.slfCtfCheck','CustInfoLayer.goNext','SlfCtfLayer.slfCtfCheck','MyBgnCnclForm.goNext','MyBgnCnclForm.doSubmit','MyFrstTrvDstcForm.goNext','MyFrstTrvDstcForm.doSubmit'],'uJ':true }},{'NQ':{'B9':['*'],'uJ':false }},[[true,{'param':{'movie':'http://www.youtube.com/*'}}],[true,{'classid':'b24fe7629dc441176d93a1648f4fd7babd80f163225e9871f279501530a4691f'}],[false,{'classid':'1822f379e18962dc9e9b3ef1ebe9310edd5792f043d6934a07a9a00eac754a10'}],[false,{'classid':'a3bea0837118cc81238f46dedd3d545f1592655d8ec2f3b37bf6f2cbeffdef93'}],[true,{'id':'c629d9cc550d188d698649e0cc77849b930c3be362e1b06ced2d89ec9c607255'}],[true,{'id':'a1a3c46ba45db2160861dce647012aa516d02530793ba204c7d5816ce2e793c7'}],[true,{'classid':'b2b645620cf2e5e6c2675e2ee877fbee8256cb03d4f39bec5c7a2086d5074919'}]],[[false,{'id':'c629d9cc550d188d698649e0cc77849b930c3be362e1b06ced2d89ec9c607255','type':'e51668405eb51c1e2e1d9c827f5033aefb4fade1dd8528c1b3512981a8f90b5c'}],[true,{'src':'http://www.youtube.com/*'}],[false,{'id':'c07f08528cf28e79f383b69855bc5509083f3e828998c36879e86d34ce27679a'}],[false,{'id':'ada654a6bf95b37d86d5ede5ed93a3c9f19636bda6abc48681169d1603341606','type':'17b07cb85fa26d4238e56f9d6300c9d540080ea932eeb06eafea4b980cc17a33'}]],{'NQ':{'B9':['*'],'uJ':false }},{'NQ':{'B9':['*'],'uJ':false }},{'NQ':{'B9':['*'],'uJ':false }},{'NQ':{'B9':['*'],'uJ':false }},{'O1':{'B9':['on'],'uJ':true },'NQ':{'B9':['*'],'uJ':false },'Hh':{'B9':['*'],'uJ':false }},{'NQ':{'B9':['*'],'uJ':false },'Hh':{'B9':['*'],'uJ':false }}]}],jw=[{'pH':['*'],'QP':[{'NQ':'data_td_id','no':function(e){return e.innerHTML;}},{'NQ':'wst_td_id1','no':function(e){ var html = e.innerHTML;if(html == ''){ return '';}else{ return html;}}}]}];var z=z||function(w,m){function e(){}var p={},f=p.l={},r=f.H={extend:function(a){e.prototype=this;var c=new e;a&&c.F(a);c.hasOwnProperty("c")||(c.c=function(){c.Z.c.apply(this,arguments)});c.c.prototype=c;c.Z=this;return c},create:function(){var a=this.extend();a.c.apply(a,arguments);return a},c:function(){},F:function(a){for(var c in a)a.hasOwnProperty(c)&&(this[c]=a[c]);a.hasOwnProperty("toString")&&(this.toString=a.toString)},f:function(){return this.c.prototype.extend(this)}},v=f.m=r.extend({c:function(a,c){a=this.d=a||[];this.a=c!=m?c:4*a.length},toString:function(a){return(a||b).stringify(this)},concat:function(a){var c=this.d,d=a.d,h=this.a;a=a.a;this.T();if(h%4)for(var u=0;u<a;u++)c[h+u>>>2]|=(d[u>>>2]>>>24-u%4*8&255)<<24-(h+u)%4*8;else if(65535<d.length)for(u=0;u<a;u+=4)c[h+u>>>2]=d[u>>>2];else c.push.apply(c,d);this.a+=a;return this},T:function(){var a=this.d,c=this.a;a[c>>>2]&=4294967295<<32-c%4*8;a.length=w.ceil(c/4)},f:function(){var a=r.f.call(this);a.d=this.d.slice(0);return a},random:function(a){for(var c=[],d=0;d<a;d+=4)c.push(4294967296*w.random()|0);return new v.c(c,a)}}),x=p.V={},b=x.za={stringify:function(a){var c=a.d;a=a.a;for(var d=[],h=0;h<a;h++){var u=c[h>>>2]>>>24-h%4*8&255;d.push((u>>>4).toString(16));d.push((u&15).toString(16))}return d.join("")},parse:function(a){for(var c=a.length,d=[],h=0;h<c;h+=2)d[h>>>3]|=parseInt(a.substr(h,2),16)<<24-h%8*4;return new v.c(d,c/2)}},y=x.Ba={stringify:function(a){var c=a.d;a=a.a;for(var d=[],h=0;h<a;h++)d.push(String.fromCharCode(c[h>>>2]>>>24-h%4*8&255));return d.join("")},parse:function(a){for(var c=a.length,d=[],h=0;h<c;h++)d[h>>>2]|=(a.charCodeAt(h)&255)<<24-h%4*8;return new v.c(d,c)}},s=x.Ga={stringify:function(a){try{return decodeURIComponent(escape(y.stringify(a)))}catch(c){throw Error("Malformed UTF-8 data");}},parse:function(a){return y.parse(unescape(encodeURIComponent(a)))}},q=f.ca=r.extend({reset:function(){this.i=new v.c;this.w= ...
# //]]></script>

# %%
cookie
# Out:
# '0001p3JKUE-DEdrG2xMPNwIxo77:1aafrjgke'

# %%
_csrf = driver.find_element_by_name('_csrf').get_attribute('value')

# %% [markdown]
# ## soup 에서 보장 내역들의 고유 코드 얻어오기

# %%
ddlist = soup.find(class_= 'plan_select').find(class_='plan_name').find_all('dd')

# %%
len(ddlist)
# Out:
# 7

# %%
for dd in ddlist : 
    print(dd.find(class_='ico_pop').get('name'))
# Out:
# cvrPop_307677
# cvrPop_305031
# cvrPop_305093
# cvrPop_305100
# cvrPop_307682
# cvrPop_311867
# cvrPop_307667

# %% [markdown]
# searchPdcCd=30581&searchSlPanCd=30&searchPymMtdCd=01&searchCvrCds=307677%2C305065%2C305069%2C305093%2C307682&searchCalcType=default&pdcDvcd=l_tooth&arcTrmCd=Y007&pymTrmCd=Y007&pymMtdCd=01&_csrf=914e1e26-22f2-4440-91e8-248041ae0f03
# ajaxLtmCalc.do 에 request할 때 필수로 넣어주어야 하는 data들
